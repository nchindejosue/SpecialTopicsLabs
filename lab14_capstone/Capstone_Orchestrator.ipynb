# %% [markdown]
# # Capstone Project: Secure AI-Assisted Codebase Editor
# **Phase 1:** GUI Architecture (Deep Blue Theme + File Management)

# %%
# CELL 1: Environment Setup
import os
import sys
import tkinter as tk

current_dir = os.getcwd()
app_path = os.path.join(current_dir, 'app')
if current_dir not in sys.path:
    sys.path.append(current_dir)

print('[OK] Environment Configured.')
# Out:
# [OK] Environment Configured.

# %%
# CELL 2: Launch the Prototype
import os
from app.main_window import SecureIDE

if __name__ == "__main__":
    print("-> Launching V3 Deep Blue Architecture...")
    app = SecureIDE()
    app.mainloop()
    print("-> Application Closed.")
# Out:
# -> Launching V3 Deep Blue Architecture...
# -> Application Closed.
